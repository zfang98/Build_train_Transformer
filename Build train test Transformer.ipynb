# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import math
import copy
import os
import zipfile
import requests
from tqdm import tqdm
import pandas as pd
import torch
import numpy as np
from transformers import AutoTokenizer
from sklearn.model_selection import train_test_split
import pandas as pd
from torch.utils.data import DataLoader, TensorDataset

# %%
# this notebook run on apple silicon chip, in order to leverage GPU:
print(torch.__version__)
print(torch.backends.mps.is_available())
# Out:
# 2.6.0
# True

# %%
## set device as mps
device = torch.device("mps")

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        # Ensure that the model dimension (d_model) is divisible by the number of heads
        assert d_model % num_heads == 0, "d_model must be divisible by num_heads"
        
        # Initialize dimensions
        self.d_model = d_model # Model's dimension
        self.num_heads = num_heads # Number of attention heads
        self.d_k = d_model // num_heads # Dimension of each head's key, query, and value
        
        # Linear layers for transforming inputs
        self.W_q = nn.Linear(d_model, d_model) # Query transformation
        self.W_k = nn.Linear(d_model, d_model) # Key transformation
        self.W_v = nn.Linear(d_model, d_model) # Value transformation
        self.W_o = nn.Linear(d_model, d_model) # Output transformation
        
    def scaled_dot_product_attention(self, Q, K, V, mask=None):
        # Calculate attention scores
        attn_scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(self.d_k)
        
        # Apply mask if provided (useful for preventing attention to certain parts like padding)
        if mask is not None:
            attn_scores = attn_scores.masked_fill(mask == 0, -1e9)
        
        # Softmax is applied to obtain attention probabilities
        attn_probs = torch.softmax(attn_scores, dim=-1)
        
        # Multiply by values to obtain the final output
        output = torch.matmul(attn_probs, V)
        return output
        
    def split_heads(self, x):
        # Reshape the input to have num_heads for multi-head attention
        batch_size, seq_length, d_model = x.size()
        return x.view(batch_size, seq_length, self.num_heads, self.d_k).transpose(1, 2)
        
    def combine_heads(self, x):
        # Combine the multiple heads back to original shape
        batch_size, _, seq_length, d_k = x.size()
        return x.transpose(1, 2).contiguous().view(batch_size, seq_length, self.d_model)
        
    def forward(self, Q, K, V, mask=None):
        # Apply linear transformations and split heads
        Q = self.split_heads(self.W_q(Q))
        K = self.split_heads(self.W_k(K))
        V = self.split_heads(self.W_v(V))
        
        # Perform scaled dot-product attention
        attn_output = self.scaled_dot_product_attention(Q, K, V, mask)
        
        # Combine heads and apply output transformation
        output = self.W_o(self.combine_heads(attn_output))
        return output

# %%
class PositionWiseFeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super(PositionWiseFeedForward, self).__init__()
        self.fc1 = nn.Linear(d_model, d_ff)
        self.fc2 = nn.Linear(d_ff, d_model)
        self.relu = nn.ReLU()

    def forward(self, x):
        return self.fc2(self.relu(self.fc1(x)))

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_seq_length, device=None):
        super(PositionalEncoding, self).__init__()
        
        pe = torch.zeros(max_seq_length, d_model, device=device)
        position = torch.arange(0, max_seq_length, dtype=torch.float, device=device).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(math.log(10000.0) / d_model))
        div_term = div_term.to(device)
        print("Input device:", pe.device)
        print("Target device:", position.device)
        print("Target device:", div_term.device)
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        
        self.register_buffer('pe', pe.unsqueeze(0))
        
    def forward(self, x):
        return x + self.pe[:, :x.size(1)]

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x, mask):
        attn_output = self.self_attn(x, x, x, mask)
        x = self.norm1(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        x = self.norm2(x + self.dropout(ff_output))
        return x

# %%
class DecoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super(DecoderLayer, self).__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.cross_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x, enc_output, src_mask, tgt_mask):
        attn_output = self.self_attn(x, x, x, tgt_mask)
        x = self.norm1(x + self.dropout(attn_output))
        attn_output = self.cross_attn(x, enc_output, enc_output, src_mask)
        x = self.norm2(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        x = self.norm3(x + self.dropout(ff_output))
        return x

# %%
class Transformer(nn.Module):
    def __init__(self, src_vocab_size, tgt_vocab_size, d_model, num_heads, num_layers, d_ff, max_seq_length, dropout):
        super(Transformer, self).__init__()
        self.encoder_embedding = nn.Embedding(src_vocab_size, d_model)
        self.decoder_embedding = nn.Embedding(tgt_vocab_size, d_model)
        self.positional_encoding = PositionalEncoding(d_model, max_seq_length, device=device)

        self.encoder_layers = nn.ModuleList([EncoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])
        self.decoder_layers = nn.ModuleList([DecoderLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])

        self.fc = nn.Linear(d_model, tgt_vocab_size)
        self.dropout = nn.Dropout(dropout)

    def generate_mask(self, src, tgt):
        src_mask = (src != 0).unsqueeze(1).unsqueeze(2).to(device)
        tgt_mask = (tgt != 0).unsqueeze(1).unsqueeze(3).to(device)
        seq_length = tgt.size(1)
        nopeak_mask = (1 - torch.triu(torch.ones(1, seq_length, seq_length), diagonal=1)).bool().to(device)
#         print (tgt_mask.shape)
#         print (nopeak_mask.shape)
        tgt_mask = tgt_mask & nopeak_mask

        return src_mask, tgt_mask

    def forward(self, src, tgt):
        src_mask, tgt_mask = self.generate_mask(src, tgt)
        src_embedded = self.dropout(self.positional_encoding(self.encoder_embedding(src)))
        tgt_embedded = self.dropout(self.positional_encoding(self.decoder_embedding(tgt)))

        enc_output = src_embedded
        for enc_layer in self.encoder_layers:
            enc_output = enc_layer(enc_output, src_mask)

        dec_output = tgt_embedded
        for dec_layer in self.decoder_layers:
            dec_output = dec_layer(dec_output, enc_output, src_mask, tgt_mask)

        output = self.fc(dec_output)
        return output

# %%
src_vocab_size = 32000
tgt_vocab_size = 32000
d_model = 512
num_heads = 8
num_layers = 6
d_ff = 2048
max_seq_length = 20
dropout = 0.1

transformer = Transformer(src_vocab_size, tgt_vocab_size, d_model, num_heads, num_layers, d_ff, max_seq_length, dropout)
# Out:
# Input device: mps:0
# Target device: mps:0
# Target device: mps:0

# %%
## Read and preprocess training, test data

# Constants
DOWNLOAD_URL = "https://opus.nlpl.eu/download.php?f=OpenSubtitles/v2018/moses/en-es.txt.zip"
EXTRACT_DIR = "/Users/fangzhang/Desktop/build_transformer/en-es.txt"
ZIP_FILE = "en-es.txt.zip"
OUTPUT_FILE = "opensubtitles_en_es.tsv"

# Step 1: Read and clean the sentence pairs

src_file_path = os.path.join(EXTRACT_DIR, "OpenSubtitles.en-es.en")
tgt_file_path = os.path.join(EXTRACT_DIR, "OpenSubtitles.en-es.es")

print("Processing sentence pairs...")
with open(src_file_path, 'r', encoding='utf-8') as src_file, \
     open(tgt_file_path, 'r', encoding='utf-8') as tgt_file, \
     open(OUTPUT_FILE, 'w', encoding='utf-8') as out_file:
    for src_line, tgt_line in tqdm(zip(src_file, tgt_file), desc="Cleaning", unit="lines"):
        src_line = src_line.strip()
        tgt_line = tgt_line.strip()
        if src_line and tgt_line and len(src_line.split()) < 50 and len(tgt_line.split()) < 50:
            out_file.write(f"{src_line}\t{tgt_line}\n")

print(f"\nSaved cleaned sentence pairs to {OUTPUT_FILE} ✅")


# Step 2: Load the TSV file with error handling
df = pd.read_csv(
    'opensubtitles_en_es.tsv',
    sep='\t',
    header=None,
    names=['en', 'es'],
    engine='python',
    on_bad_lines='warn'  # Skips bad lines and warns about them
)

# Step 3: processing
# Drop rows with null values
df.dropna(inplace=True)

# Filter sentence pairs by length
df = df[df['en'].str.split().str.len().between(3, 50)]
df = df[df['es'].str.split().str.len().between(3, 50)]

# Remove duplicate pairs
df.drop_duplicates(inplace=True)

# Reset index
df.reset_index(drop=True, inplace=True)


# Step 4: Initialize tokenizers for English and Spanish
tokenizer_en = AutoTokenizer.from_pretrained('bert-base-uncased')
tokenizer_es = AutoTokenizer.from_pretrained('dccuchile/bert-base-spanish-wwm-cased')

# Tokenize the sentences
df['en_tokens'] = df['en'].apply(lambda x: tokenizer_en.encode(x, add_special_tokens=True))
df['es_tokens'] = df['es'].apply(lambda x: tokenizer_es.encode(x, add_special_tokens=True))



# Step 5: Split into training and temp (which will be further split into validation and test)
train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42)

# Split temp into validation and test
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)



# Example pandas Series
# Each value is a list of integers representing tokens

# Parameters
max_len = 20
pad_token = 0  # You can choose any value as the padding token

# Step 6: convert to tensors

def gen_tensor(s):

    # Pad or truncate each list
    padded = s.apply(lambda x: (x + [pad_token]*max_len)[:max_len])

    # Convert to tensor
    data = torch.tensor(padded.tolist(), dtype=torch.long)
    return data

src_data = gen_tensor(train_df['en_tokens'])
tgt_data = gen_tensor(train_df['es_tokens'])

src_test = gen_tensor(test_df['en_tokens'])
tgt_test = gen_tensor(test_df['es_tokens'])
# Out:
# Processing sentence pairs...
# Cleaning: 506188lines [00:00, 530722.85lines/s]
# Skipping line 589: '	' expected after '"'
# Skipping line 1782: '	' expected after '"'
# Skipping line 2129: '	' expected after '"'
# Skipping line 2352: '	' expected after '"'
# Skipping line 2353: '	' expected after '"'
# Skipping line 2354: '	' expected after '"'
# Skipping line 2580: '	' expected after '"'
# Skipping line 2882: '	' expected after '"'
# Skipping line 2883: '	' expected after '"'
# Skipping line 2908: '	' expected after '"'
# Skipping line 2910: '	' expected after '"'
# Skipping line 2911: '	' expected after '"'
# Skipping line 3355: '	' expected after '"'
# Skipping line 3703: '	' expected after '"'
# Skipping line 4442: '	' expected after '"'
# Skipping line 4696: '	' expected after '"'
# Skipping line 4758: '	' expected after '"'
# Skipping line 4759: '	' expected after '"'
# Skipping line 4760: '	' expected after '"'
# Skipping line 4841: '	' expected after '"'
# Skipping line 4842: '	' expected after '"'
# Skipping line 4843: '	' expected after '"'
# Skipping line 5357: '	' expected after '"'
# Skipping line 5394: '	' expected after '"'
# Skipping line 6289: '	' expected after '"'
# Skipping line 6291: '	' expected after '"'
# Skipping line 6880: '	' expected after '"'
# Skipping line 7150: '	' expected after '"'
# Skipping line 7242: '	' expected after '"'
# Skipping line 7327: '	' expected after '"'
# Skipping line 9631: '	' expected after '"'
# Skipping line 9739: '	' expected after '"'
# Skipping line 10023: '	' expected after '"'
# Skipping line 10563: '	' expected after '"'
# Skipping line 11454: '	' expected after '"'
# Skipping line 12778: '	' expected after '"'
# Skipping line 12955: '	' expected after '"'
# Skipping line 12956: '	' expected after '"'
# Skipping line 12990: '	' expected after '"'
# Skipping line 13231: '	' expected after '"'
# Skipping line 13303: '	' expected after '"'
# Skipping line 13649: '	' expected after '"'
# Skipping line 13931: '	' expected after '"'
# Skipping line 13995: '	' expected after '"'
# Skipping line 14053: '	' expected after '"'
# Skipping line 14218: '	' expected after '"'
# Skipping line 14778: '	' expected after '"'
# Skipping line 15079: '	' expected after '"'
# Skipping line 15108: '	' expected after '"'
# Skipping line 15132: '	' expected after '"'
# Skipping line 15162: '	' expected after '"'
# Skipping line 15199: '	' expected after '"'
# Skipping line 15343: '	' expected after '"'
# Skipping line 15670: '	' expected after '"'
# Skipping line 15828: '	' expected after '"'
# Skipping line 15863: '	' expected after '"'
# Skipping line 16008: '	' expected after '"'
# Skipping line 16066: '	' expected after '"'
# Skipping line 16490: '	' expected after '"'
# Skipping line 16491: '	' expected after '"'
# Skipping line 16492: '	' expected after '"'
# Skipping line 16595: '	' expected after '"'
# Skipping line 16596: '	' expected after '"'
# Skipping line 16597: '	' expected after '"'
# Skipping line 16657: '	' expected after '"'
# Skipping line 16770: '	' expected after '"'
# Skipping line 16894: '	' expected after '"'
# Skipping line 17021: '	' expected after '"'
# Skipping line 17871: '	' expected after '"'
# Skipping line 17890: '	' expected after '"'
# Skipping line 17900: '	' expected after '"'
# Skipping line 17903: '	' expected after '"'
# Skipping line 17904: '	' expected after '"'
# Skipping line 17905: '	' expected after '"'
# Skipping line 17909: '	' expected after '"'
# Skipping line 17910: '	' expected after '"'
# Skipping line 17938: '	' expected after '"'
# Skipping line 18204: '	' expected after '"'
# Skipping line 18438: '	' expected after '"'
# Skipping line 18490: '	' expected after '"'
# Skipping line 18494: '	' expected after '"'
# Skipping line 18532: '	' expected after '"'
# Skipping line 19129: '	' expected after '"'
# Skipping line 19172: '	' expected after '"'
# Skipping line 19670: '	' expected after '"'
# Skipping line 19700: '	' expected after '"'
# Skipping line 20123: '	' expected after '"'
# Skipping line 20465: '	' expected after '"'
# Skipping line 20660: '	' expected after '"'
# Skipping line 20665: '	' expected after '"'
# Skipping line 20671: '	' expected after '"'
# Skipping line 20675: '	' expected after '"'
# Skipping line 20680: '	' expected after '"'
# Skipping line 20685: '	' expected after '"'
# Skipping line 21005: '	' expected after '"'
# Skipping line 21016: '	' expected after '"'
# Skipping line 21158: '	' expected after '"'
# Skipping line 21244: '	' expected after '"'
# Skipping line 21529: '	' expected after '"'
# Skipping line 21682: '	' expected after '"'
# Skipping line 21898: '	' expected after '"'
# Skipping line 22287: '	' expected after '"'
# Skipping line 22550: '	' expected after '"'
# Skipping line 22785: '	' expected after '"'
# Skipping line 23846: '	' expected after '"'
# Skipping line 24722: '	' expected after '"'
# Skipping line 25273: '	' expected after '"'
# Skipping line 25463: '	' expected after '"'
# Skipping line 27732: '	' expected after '"'
# Skipping line 28158: '	' expected after '"'
# Skipping line 28267: '	' expected after '"'
# Skipping line 28268: '	' expected after '"'
# Skipping line 29096: '	' expected after '"'
# Skipping line 29162: '	' expected after '"'
# Skipping line 29331: '	' expected after '"'
# Skipping line 29695: '	' expected after '"'
# Skipping line 29768: '	' expected after '"'
# Skipping line 30141: '	' expected after '"'
# Skipping line 30997: '	' expected after '"'
# Skipping line 30998: '	' expected after '"'
# Skipping line 31385: '	' expected after '"'
# Skipping line 32106: '	' expected after '"'
# Skipping line 32195: '	' expected after '"'
# Skipping line 32499: '	' expected after '"'
# Skipping line 32821: '	' expected after '"'
# Skipping line 33179: '	' expected after '"'
# Skipping line 33372: '	' expected after '"'
# Skipping line 33904: '	' expected after '"'
# Skipping line 34140: '	' expected after '"'
# Skipping line 35284: '	' expected after '"'
# Skipping line 35342: '	' expected after '"'
# Skipping line 35373: '	' expected after '"'
# Skipping line 35492: '	' expected after '"'
# Skipping line 35495: '	' expected after '"'
# Skipping line 35530: '	' expected after '"'
# Skipping line 37394: '	' expected after '"'
# Skipping line 37967: '	' expected after '"'
# Skipping line 38700: '	' expected after '"'
# Skipping line 38801: '	' expected after '"'
# Skipping line 39435: '	' expected after '"'
# Skipping line 41449: '	' expected after '"'
# Skipping line 41671: '	' expected after '"'
# Skipping line 41735: '	' expected after '"'
# Skipping line 41790: '	' expected after '"'
# Skipping line 41871: '	' expected after '"'
# Skipping line 41874: '	' expected after '"'
# Skipping line 41875: '	' expected after '"'
# Skipping line 42022: '	' expected after '"'
# Skipping line 42085: '	' expected after '"'
# Skipping line 42316: '	' expected after '"'
# Skipping line 42333: '	' expected after '"'
# Skipping line 42464: '	' expected after '"'
# Skipping line 42465: '	' expected after '"'
# Skipping line 42467: '	' expected after '"'
# Skipping line 42468: '	' expected after '"'
# Skipping line 42470: '	' expected after '"'
# Skipping line 45300: '	' expected after '"'
# Skipping line 45301: '	' expected after '"'
# Skipping line 45990: '	' expected after '"'
# Skipping line 46068: '	' expected after '"'
# Skipping line 46199: '	' expected after '"'
# Skipping line 46204: '	' expected after '"'
# Skipping line 46218: '	' expected after '"'
# Skipping line 46219: '	' expected after '"'
# Skipping line 46228: '	' expected after '"'
# Skipping line 46232: '	' expected after '"'
# Skipping line 46234: '	' expected after '"'
# Skipping line 46238: '	' expected after '"'
# Skipping line 46240: '	' expected after '"'
# Skipping line 46272: '	' expected after '"'
# Skipping line 46396: '	' expected after '"'
# Skipping line 46418: '	' expected after '"'
# Skipping line 46427: '	' expected after '"'
# Skipping line 46532: '	' expected after '"'
# Skipping line 47182: '	' expected after '"'
# Skipping line 48477: '	' expected after '"'
# Skipping line 48746: '	' expected after '"'
# Skipping line 49219: '	' expected after '"'
# Skipping line 49261: '	' expected after '"'
# Skipping line 49379: '	' expected after '"'
# Skipping line 49382: '	' expected after '"'
# Skipping line 49420: '	' expected after '"'
# Skipping line 49699: '	' expected after '"'
# Skipping line 49700: '	' expected after '"'
# Skipping line 49766: '	' expected after '"'
# Skipping line 49824: '	' expected after '"'
# Skipping line 50198: '	' expected after '"'
# Skipping line 50217: '	' expected after '"'
# Skipping line 50268: '	' expected after '"'
# Skipping line 51254: '	' expected after '"'
# Skipping line 51492: '	' expected after '"'
# Skipping line 52922: '	' expected after '"'
# Saved cleaned sentence pairs to opensubtitles_en_es.tsv ✅
# Skipping line 56478: '	' expected after '"'
# Skipping line 56483: '	' expected after '"'
# Skipping line 56488: '	' expected after '"'
# Skipping line 56643: '	' expected after '"'
# Skipping line 56785: '	' expected after '"'
# Skipping line 57653: '	' expected after '"'
# Skipping line 59496: '	' expected after '"'
# Skipping line 59943: '	' expected after '"'
# Skipping line 59990: '	' expected after '"'
# Skipping line 60333: '	' expected after '"'
# Skipping line 60651: '	' expected after '"'
# Skipping line 60652: '	' expected after '"'
# Skipping line 60654: '	' expected after '"'
# Skipping line 60655: '	' expected after '"'
# Skipping line 60658: '	' expected after '"'
# Skipping line 60659: '	' expected after '"'
# Skipping line 60660: '	' expected after '"'
# Skipping line 60661: '	' expected after '"'
# Skipping line 60662: '	' expected after '"'
# Skipping line 60663: '	' expected after '"'
# Skipping line 60668: '	' expected after '"'
# Skipping line 60669: '	' expected after '"'
# Skipping line 60670: '	' expected after '"'
# Skipping line 60671: '	' expected after '"'
# Skipping line 60672: '	' expected after '"'
# Skipping line 60673: '	' expected after '"'
# Skipping line 60674: '	' expected after '"'
# Skipping line 60675: '	' expected after '"'
# Skipping line 60676: '	' expected after '"'
# Skipping line 60680: '	' expected after '"'
# Skipping line 60681: '	' expected after '"'
# Skipping line 60682: '	' expected after '"'
# Skipping line 60683: '	' expected after '"'
# Skipping line 60684: '	' expected after '"'
# Skipping line 60685: '	' expected after '"'
# Skipping line 60686: '	' expected after '"'
# Skipping line 60687: '	' expected after '"'
# Skipping line 60692: '	' expected after '"'
# Skipping line 60693: '	' expected after '"'
# Skipping line 61115: '	' expected after '"'
# Skipping line 61894: '	' expected after '"'
# Skipping line 62103: '	' expected after '"'
# Skipping line 63248: '	' expected after '"'
# Skipping line 64180: '	' expected after '"'
# Skipping line 65745: '	' expected after '"'
# Skipping line 65760: '	' expected after '"'
# Skipping line 65952: '	' expected after '"'
# Skipping line 66977: '	' expected after '"'
# Skipping line 68083: '	' expected after '"'
# Skipping line 68189: '	' expected after '"'
# Skipping line 69231: '	' expected after '"'
# Skipping line 69232: '	' expected after '"'
# Skipping line 69238: '	' expected after '"'
# Skipping line 69272: '	' expected after '"'
# Skipping line 69321: '	' expected after '"'
# Skipping line 69323: '	' expected after '"'
# Skipping line 69326: '	' expected after '"'
# Skipping line 69329: '	' expected after '"'
# Skipping line 69386: '	' expected after '"'
# Skipping line 69392: '	' expected after '"'
# Skipping line 69398: '	' expected after '"'
# Skipping line 487302: '	' expected after '"'
# Skipping line 487303: '	' expected after '"'
# Skipping line 487466: '	' expected after '"'
# Skipping line 487469: '	' expected after '"'
# Skipping line 487472: '	' expected after '"'
# Skipping line 487538: '	' expected after '"'
# Skipping line 487862: '	' expected after '"'
# Skipping line 487891: '	' expected after '"'
# Skipping line 487941: '	' expected after '"'
# Skipping line 488117: '	' expected after '"'
# Skipping line 488979: '	' expected after '"'
# Skipping line 488989: '	' expected after '"'
# Skipping line 488990: '	' expected after '"'
# Skipping line 489045: '	' expected after '"'
# Skipping line 489046: '	' expected after '"'
# Skipping line 489387: '	' expected after '"'
# Skipping line 489581: '	' expected after '"'
# Skipping line 490300: '	' expected after '"'
# Skipping line 490701: '	' expected after '"'
# Skipping line 491101: '	' expected after '"'
# Skipping line 491380: '	' expected after '"'
# Skipping line 491609: '	' expected after '"'
# Skipping line 491653: '	' expected after '"'
# Skipping line 491664: '	' expected after '"'
# Skipping line 491666: '	' expected after '"'
# Skipping line 491794: '	' expected after '"'
# Skipping line 491834: '	' expected after '"'
# Skipping line 491842: '	' expected after '"'
# Skipping line 491846: '	' expected after '"'
# Skipping line 492542: '	' expected after '"'
# Skipping line 492840: '	' expected after '"'
# Skipping line 493749: '	' expected after '"'
# Skipping line 494000: '	' expected after '"'
# Skipping line 496442: '	' expected after '"'
# Skipping line 496560: '	' expected after '"'
# Skipping line 496956: '	' expected after '"'
# Skipping line 497155: '	' expected after '"'
# Skipping line 497221: '	' expected after '"'
# Skipping line 497302: '	' expected after '"'
# Skipping line 497438: '	' expected after '"'
# Skipping line 497456: '	' expected after '"'
# Skipping line 497946: '	' expected after '"'
# Skipping line 498612: '	' expected after '"'
# Skipping line 498651: '	' expected after '"'
# Skipping line 498849: '	' expected after '"'
# Skipping line 499173: '	' expected after '"'
# Skipping line 499678: '	' expected after '"'
# Skipping line 499699: '	' expected after '"'
# Skipping line 500114: '	' expected after '"'
# Skipping line 500195: '	' expected after '"'
# Skipping line 500481: '	' expected after '"'
# Skipping line 500833: '	' expected after '"'
# Skipping line 13493: Expected 2 fields in line 13493, saw 3
# Skipping line 41578: Expected 2 fields in line 41578, saw 3
# Skipping line 65714: Expected 2 fields in line 65714, saw 3
# Skipping line 72980: Expected 2 fields in line 72980, saw 3
# Skipping line 74945: Expected 2 fields in line 74945, saw 3
# Skipping line 104157: Expected 2 fields in line 104157, saw 3
# Skipping line 105090: Expected 2 fields in line 105090, saw 3
# Skipping line 110553: Expected 2 fields in line 110553, saw 3
# Skipping line 131137: Expected 2 fields in line 131137, saw 3
# Skipping line 131180: Expected 2 fields in line 131180, saw 3
# Skipping line 131245: Expected 2 fields in line 131245, saw 3
# Skipping line 131495: Expected 2 fields in line 131495, saw 3
# Skipping line 131520: Expected 2 fields in line 131520, saw 3
# Skipping line 131536: Expected 2 fields in line 131536, saw 3
# Skipping line 131557: Expected 2 fields in line 131557, saw 3
# Skipping line 131565: Expected 2 fields in line 131565, saw 3
# Skipping line 131568: Expected 2 fields in line 131568, saw 3
# Skipping line 131613: Expected 2 fields in line 131613, saw 3
# Skipping line 131639: Expected 2 fields in line 131639, saw 3
# Skipping line 131642: Expected 2 fields in line 131642, saw 3
# Skipping line 131643: Expected 2 fields in line 131643, saw 3
# Skipping line 131684: Expected 2 fields in line 131684, saw 3
# Skipping line 131740: Expected 2 fields in line 131740, saw 3
# Skipping line 131803: Expected 2 fields in line 131803, saw 3
# Skipping line 131805: Expected 2 fields in line 131805, saw 3
# Skipping line 131810: Expected 2 fields in line 131810, saw 3
# Skipping line 142510: Expected 2 fields in line 142510, saw 3
# Skipping line 145348: Expected 2 fields in line 145348, saw 3
# Skipping line 145377: Expected 2 fields in line 145377, saw 3
# Skipping line 153439: Expected 2 fields in line 153439, saw 3
# Skipping line 175992: Expected 2 fields in line 175992, saw 3
# Skipping line 178954: Expected 2 fields in line 178954, saw 3
# Skipping line 182939: Expected 2 fields in line 182939, saw 3
# Skipping line 184952: Expected 2 fields in line 184952, saw 3
# Skipping line 186042: Expected 2 fields in line 186042, saw 3
# Skipping line 236662: Expected 2 fields in line 236662, saw 3
# Skipping line 242757: Expected 2 fields in line 242757, saw 3
# Skipping line 262471: Expected 2 fields in line 262471, saw 3
# Skipping line 262670: Expected 2 fields in line 262670, saw 3
# Skipping line 262802: Expected 2 fields in line 262802, saw 3
# Skipping line 272803: Expected 2 fields in line 272803, saw 3
# Skipping line 272804: Expected 2 fields in line 272804, saw 3
# Skipping line 278886: Expected 2 fields in line 278886, saw 3
# Skipping line 283477: Expected 2 fields in line 283477, saw 3
# Skipping line 284306: Expected 2 fields in line 284306, saw 3
# Skipping line 285971: Expected 2 fields in line 285971, saw 3
# Skipping line 286030: Expected 2 fields in line 286030, saw 3
# Skipping line 286379: Expected 2 fields in line 286379, saw 3
# Skipping line 288224: Expected 2 fields in line 288224, saw 3
# Skipping line 290894: Expected 2 fields in line 290894, saw 3
# Skipping line 295330: Expected 2 fields in line 295330, saw 3
# Skipping line 313556: Expected 2 fields in line 313556, saw 3
# Skipping line 314305: Expected 2 fields in line 314305, saw 3
# Skipping line 315735: Expected 2 fields in line 315735, saw 3
# Skipping line 316870: Expected 2 fields in line 316870, saw 3
# Skipping line 316968: Expected 2 fields in line 316968, saw 3
# Skipping line 317105: Expected 2 fields in line 317105, saw 3
# Skipping line 317539: Expected 2 fields in line 317539, saw 3
# Skipping line 317541: Expected 2 fields in line 317541, saw 3
# Skipping line 317561: Expected 2 fields in line 317561, saw 3
# Skipping line 317992: Expected 2 fields in line 317992, saw 3
# Skipping line 318201: Expected 2 fields in line 318201, saw 3
# Skipping line 318475: Expected 2 fields in line 318475, saw 3
# Skipping line 322755: Expected 2 fields in line 322755, saw 3
# Skipping line 329947: Expected 2 fields in line 329947, saw 3
# Skipping line 332877: Expected 2 fields in line 332877, saw 3
# Skipping line 335950: Expected 2 fields in line 335950, saw 3
# Skipping line 336028: Expected 2 fields in line 336028, saw 3
# Skipping line 345615: Expected 2 fields in line 345615, saw 3
# Skipping line 351830: Expected 2 fields in line 351830, saw 3
# Skipping line 352223: Expected 2 fields in line 352223, saw 3
# Skipping line 356145: Expected 2 fields in line 356145, saw 3
# Skipping line 386281: Expected 2 fields in line 386281, saw 3
# Skipping line 403642: Expected 2 fields in line 403642, saw 3
# Skipping line 403888: Expected 2 fields in line 403888, saw 3
# Skipping line 406409: Expected 2 fields in line 406409, saw 3
# Skipping line 419751: Expected 2 fields in line 419751, saw 3
# Skipping line 421775: Expected 2 fields in line 421775, saw 3
# Skipping line 458276: Expected 2 fields in line 458276, saw 3

# %%
src_data.shape
# Out:
# torch.Size([284734, 20])

# %%
criterion = nn.CrossEntropyLoss(ignore_index=0)
optimizer = optim.Adam(transformer.parameters(), lr=0.0001, betas=(0.9, 0.98), eps=1e-9)

model = transformer
model.to(device)

# transformer.train()
model.train()
# Out:
# Transformer(
#   (encoder_embedding): Embedding(32000, 512)
#   (decoder_embedding): Embedding(32000, 512)
#   (positional_encoding): PositionalEncoding()
#   (encoder_layers): ModuleList(
#     (0-5): 6 x EncoderLayer(
#       (self_attn): MultiHeadAttention(
#         (W_q): Linear(in_features=512, out_features=512, bias=True)
#         (W_k): Linear(in_features=512, out_features=512, bias=True)
#         (W_v): Linear(in_features=512, out_features=512, bias=True)
#         (W_o): Linear(in_features=512, out_features=512, bias=True)
#       )
#       (feed_forward): PositionWiseFeedForward(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (relu): ReLU()
#       )
#       (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (decoder_layers): ModuleList(
#     (0-5): 6 x DecoderLayer(
#       (self_attn): MultiHeadAttention(
#         (W_q): Linear(in_features=512, out_features=512, bias=True)
#         (W_k): Linear(in_features=512, out_features=512, bias=True)
#         (W_v): Linear(in_features=512, out_features=512, bias=True)
#         (W_o): Linear(in_features=512, out_features=512, bias=True)
#       )
#       (cross_attn): MultiHeadAttention(
#         (W_q): Linear(in_features=512, out_features=512, bias=True)
#         (W_k): Linear(in_features=512, out_features=512, bias=True)
#         (W_v): Linear(in_features=512, out_features=512, bias=True)
#         (W_o): Linear(in_features=512, out_features=512, bias=True)
#       )
#       (feed_forward): PositionWiseFeedForward(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (relu): ReLU()
#       )
#       (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (norm3): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (fc): Linear(in_features=512, out_features=32000, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )

# %%
dataset = TensorDataset(src_data, tgt_data)

# Create DataLoader with batching
loader = DataLoader(dataset, batch_size=64, shuffle=True)

# Usage in training loop
for batch in loader:
    src_batch, tgt_batch = batch  # both are shape (batch_size, seq_len)
    src_batch, tgt_batch = src_batch.to(device), tgt_batch.to(device)
    # Feed into transformer model here
    
    for epoch in range(2):
        optimizer.zero_grad()
        output = model(src_batch, tgt_batch[:, :-1])
        loss = criterion(output.contiguous().view(-1, tgt_vocab_size), tgt_batch[:, 1:].contiguous().view(-1))
        loss.backward()
        optimizer.step()
        print(f"Epoch: {epoch+1}, Loss: {loss.item()}")

# %%
transformer.eval()

src_test = gen_tensor(test_df.iloc[:1900,2])
tgt_test = gen_tensor(test_df.iloc[:1900,3])
src_test, tgt_test = src_test.to(device), tgt_test.to(device)

with torch.no_grad():

    val_output = transformer(src_test, tgt_test[:, :-1])
    val_loss = criterion(val_output.contiguous().view(-1, tgt_vocab_size), tgt_test[:, 1:].contiguous().view(-1))
    print(f"Validation Loss: {val_loss.item()}")
# Out:
# Validation Loss: 3.561875820159912
